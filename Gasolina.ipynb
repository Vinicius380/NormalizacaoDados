# %%
import pandas as pd

# %%
data_gasolina2000 = pd.read_csv("gasolina_2000+.csv")

linhasVazias = data_gasolina2000.isnull().sum()
linhasVazias
# Out:
# Unnamed: 0                       0
# DATA INICIAL                     0
# DATA FINAL                       0
# REGIÃO                           1
# ESTADO                           2
# PRODUTO                          1
# NÚMERO DE POSTOS PESQUISADOS     0
# UNIDADE DE MEDIDA                0
# PREÇO MÉDIO REVENDA              0
# DESVIO PADRÃO REVENDA            0
# PREÇO MÍNIMO REVENDA             1
# PREÇO MÁXIMO REVENDA             0
# MARGEM MÉDIA REVENDA             0
# COEF DE VARIAÇÃO REVENDA         0
# PREÇO MÉDIO DISTRIBUIÇÃO         0
# DESVIO PADRÃO DISTRIBUIÇÃO       0
# PREÇO MÍNIMO DISTRIBUIÇÃO        0
# PREÇO MÁXIMO DISTRIBUIÇÃO        0
# COEF DE VARIAÇÃO DISTRIBUIÇÃO    0
# dtype: int64

# %%
colunaNovas = data_gasolina2000.rename(columns={"DATA INICIAL":"DT.Inicial", "DATA FINAL":"DT.Final", "REGIÃO":"Divisão territorial", "PRODUTO":"Item"})

colunaNovas

data_gasolina2000 = colunaNovas

# %%
data_gasolina2000.to_csv("dados_gasolina2000.csv", index=False)

# %%
data_gasolina2010 = pd.read_csv("gasolina_2010+.csv")
data_gasolina2010
# Out:
# C:\Users\50749314877\AppData\Local\Temp\ipykernel_15364\1269883053.py:1: DtypeWarning: Columns (12,14,15,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_gasolina2010 = pd.read_csv("gasolina_2010+.csv")
#        Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0            9256   2011-01-02  2011-01-08  CENTRO OESTE    DISTRITO FEDERAL
# 1            9257   2011-01-02  2011-01-08  CENTRO OESTE               GOIAS
# 2            9258   2011-01-02  2011-01-08  CENTRO OESTE         MATO GROSSO
# 3            9259   2011-01-02  2011-01-08  CENTRO OESTE  MATO GROSSO DO SUL
# 4            9260   2011-01-02  2011-01-08      NORDESTE             ALAGOAS
# ...           ...          ...         ...           ...                 ...
# 78180      120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 78181      120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# ...

# %%
data_gasolina2000
# Out:
#        Unnamed: 0  DT.Inicial    DT.Final Divisão territorial  \
# 0               0  2004-05-09  2004-05-15        CENTRO OESTE
# 1               1  2004-05-09  2004-05-15        CENTRO OESTE
# 2               2  2004-05-09  2004-05-15        CENTRO OESTE
# 3               3  2004-05-09  2004-05-15        CENTRO OESTE
# 4               4  2004-05-09  2004-05-15            NORDESTE
# ...           ...         ...         ...                 ...
# 42633       52802  2010-12-26  2011-01-01             SUDESTE
# 42634       52803  2010-12-26  2011-01-01             SUDESTE
# 42635       52804  2010-12-26  2011-01-01                 SUL
# 42636       52805  2010-12-26  2011-01-01                 SUL
# 42637       52806  2010-12-26  2011-01-01                 SUL
#
#                    ESTADO              Item  NÚMERO DE POSTOS PESQUISADOS  \
# 0        DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# ...
